# %%
# fundamentals
import pandas as pd
import numpy as np
from pathlib import Path

# %%
shots = pd.read_csv(Path('data')/'NBA_2022_Shots.csv')
shots.head()
# Out:
#    SEASON_1 SEASON_2     TEAM_ID           TEAM_NAME  PLAYER_ID  \
# 0      2022  2021-22  1610612747  Los Angeles Lakers    1630644
# 1      2022  2021-22  1610612743      Denver Nuggets    1630210
# 2      2022  2021-22  1610612747  Los Angeles Lakers    1630559
# 3      2022  2021-22  1610612747  Los Angeles Lakers    1630559
# 4      2022  2021-22  1610612743      Denver Nuggets    1630192
#
#      PLAYER_NAME POSITION_GROUP POSITION   GAME_DATE   GAME_ID  ...  \
# 0    Mac McClung              G    SG-PG  04-10-2022  22101220  ...
# 1  Markus Howard              G       SG  04-10-2022  22101220  ...
# 2  Austin Reaves              G       SG  04-10-2022  22101220  ...
# 3  Austin Reaves              G       SG  04-10-2022  22101220  ...
# 4     Zeke Nnaji              F       PF  04-10-2022  22101220  ...
#
#           BASIC_ZONE         ZONE_NAME ZONE_ABB       ZONE_RANGE LOC_X  LOC_Y  \
# 0    Restricted Area            Center        C  Less Than 8 ft.  0.07  5.935
# ...

# %%
all_stars = ['LeBron James', 'Kevin Durant', 'Giannis Antetokounmpo', 'Joel Embiid', 'Stephen Curry', 
             'Ja Morant', 'DeMar DeRozan', 'Jayson Tatum', 'Nikola Jokic', 'Andrew Wiggins', 'Trae Young', 
             'Devin Booker', 'Luka Doncic', 'Karl-Anthony Towns', 'Darius Garland', 'Zach LaVine', 
             'Chris Paul', 'Dejounte Murray', 'Jimmy Butler', 'Khris Middleton', 'Donovan Mitchell', 
             'LaMelo Ball', 'Fred VanVleet', 'Rudy Gobert', 'James Harden']

# %%
stars = shots[shots['PLAYER_NAME'].isin(all_stars)]
stars.head()
# Out:
#      SEASON_1 SEASON_2     TEAM_ID          TEAM_NAME  PLAYER_ID  \
# 133      2022  2021-22  1610612766  Charlotte Hornets    1630163
# 194      2022  2021-22  1610612766  Charlotte Hornets    1630163
# 222      2022  2021-22  1610612751      Brooklyn Nets     201142
# 259      2022  2021-22  1610612751      Brooklyn Nets     201142
# 320      2022  2021-22  1610612737      Atlanta Hawks    1629027
#
#       PLAYER_NAME POSITION_GROUP POSITION   GAME_DATE   GAME_ID  ...  \
# 133   LaMelo Ball              G       PG  04-10-2022  22101217  ...
# 194   LaMelo Ball              G       PG  04-10-2022  22101217  ...
# 222  Kevin Durant              F       PF  04-10-2022  22101216  ...
# 259  Kevin Durant              F       PF  04-10-2022  22101216  ...
# 320    Trae Young              G       PG  04-10-2022  22101221  ...
#
#                 BASIC_ZONE          ZONE_NAME ZONE_ABB  ZONE_RANGE LOC_X  \
# 133      Above the Break 3             Center        C     24+ ft. -0.76
# ...

# %%
stars['SHOT_MADE']
# Out:
# 133        True
# 194        True
# 222       False
# 259        True
# 320        True
#           ...
# 216708    False
# 216709     True
# 216711    False
# 216715    False
# 216717    False
# Name: SHOT_MADE, Length: 29740, dtype: bool

# %%
stars.loc[:, 'SHOT_MADE'] = stars['SHOT_MADE'].apply(lambda x: 1 if x == True else 0)
# Out:
# /var/folders/lt/n_z12_lx2cb6n9qf36pmd3x40000gn/T/ipykernel_60147/4118830606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stars.loc[:, 'SHOT_MADE'] = stars['SHOT_MADE'].apply(lambda x: 1 if x == True else 0)

# %%
stars_stats = stars.groupby(['PLAYER_NAME', 'BASIC_ZONE'])[['SHOT_MADE']].agg(['sum', 'count', 'mean'])

# %%
stars_stats.to_json(Path('data')/'allstar_stats.json')
